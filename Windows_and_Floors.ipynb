# %% [markdown]
# <a href="https://colab.research.google.com/github/tukulkumar/tukul/blob/main/Windows_and_Floors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
from IPython import display
from IPython.display import display, Image

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 3.9 MB/s eta 0:00:00
# ...

# %%
pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.4/78.2 GB disk)

# %%
from ultralytics import YOLO

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="EKhBcrEKuJiC3QpsTwl7")
project = rf.workspace("tukul-kumar").project("final-element-detection")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.227, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to FInal-Element-detection-1 in yolov8:: 100%|██████████| 5940/5940 [00:01<00:00, 4019.70it/s]

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 77.4MB/s]

# %%
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
# ...

# %%
model.predict(source='/content/FInal-Element-detection-1/test.jpg', conf=0.35, save=True)
# Out:
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/FInal-Element-detection-1/test.jpg: 448x640 1 cup, 1 tv, 1 mouse, 1 keyboard, 1 cell phone, 5 vases, 110.4ms
# Speed: 4.9ms preprocess, 110.4ms inference, 746.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
Image(filename=f'{HOME}/runs/detect/predict/test.jpg', width=600)

# %%
model.train(data='/content/FInal-Element-detection-1/data.yaml', epochs=10, plots = True)
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/confusion_matrix.png', width=600)
# Out:
# /content

# %%
Image(filename=f'{HOME}/runs/detect/train2/results.png', width=600)

# %%
model= YOLO('/content/runs/detect/train2/weights/best.pt')

# %%
model.val(data='/content/FInal-Element-detection-1/data.yaml')
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/FInal-Element-detection-1/valid/labels.cache... 598 images, 0 backgrounds, 0 corrupt: 100%|██████████| 598/598 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/FInal-Element-detection-1/valid/images/cmp_b0091_jpg.rf.bdedd38c7b30789881be75fe40469a15.jpg: 1 duplicate labels removed
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 17082, len(boxes) = 17167. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  11%|█         | 4/38 [00:09<01:28,  2.61s/it]
# WARNING ⚠️ NMS time limit 1.300s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 38/38 [00:40<00:00,  1.05s/it]
# ...

# %%
import torch

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# ANSI_X3.4-1968

# %%
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16111, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 16111 (delta 7), reused 5 (delta 0), pack-reused 16089
# Receiving objects: 100% (16111/16111), 14.79 MiB | 25.03 MiB/s, done.
# Resolving deltas: 100% (11031/11031), done.

# %%
# !pip install -U -r yolov5/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 46.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 22.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 62.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.5/285.5 kB 38.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 668.9 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 59.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 56.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 38.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 55.2 MB/s eta 0:00:00
# ...

# %%
rf = Roboflow(api_key="EKhBcrEKuJiC3QpsTwl7")
project = rf.workspace("tukul-kumar").project("final-element-detection")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to FInal-Element-detection-1 in yolov5pytorch:: 100%|██████████| 5940/5940 [00:02<00:00, 2611.58it/s]

# %%
os.environ["DATASET_DIRECTORY"] = "/content/FInal-Element-detection-1"

# %%
#!python /content/yolov5/train.py --img 416 --batch 16 --epochs 15 --data {/content/FInal-Element-detection-1}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-12-19 06:04:44.243695: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-19 06:04:44.243751: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-19 06:04:44.246027: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
model1 = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-12-19 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# %cd /content/yolov5/
# Out:
# /content/yolov5

# %%
#model1.train( data='/content/FInal-Element-detection-1/data.yaml', epochs = 15, size = 416, batch_size=16,plots = True)

# %%
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 15 --data {dataset.location}/data.yaml --weights model1 --cache --cfg ./models/yolov5s.yaml
# Out:
# /content/yolov5
# 2023-12-19 07:11:14.139292: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-19 07:11:14.139399: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-19 07:11:14.231406: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd {HOME}
# Out:
# /content

# %%
Image(filename=f'{HOME}/yolov5/runs/train/exp8/confusion_matrix.png', width=600)

# %%
Image(filename=f'{HOME}/yolov5/runs/train/exp8/results.png', width=600)

# %%
model.train(data='/content/FInal-Element-detection-1/data.yaml', epochs=25, plots = True)
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'{HOME}/runs/detect/train3/confusion_matrix.png', width=600)

# %%
Image(filename=f'{HOME}/runs/detect/train3/F1_curve.png', width=600)

# %%
Image(filename=f'{HOME}/runs/detect/train3/PR_curve.png', width=600)

# %%
Image(filename=f'{HOME}/runs/detect/train3/results.png', width=600)
